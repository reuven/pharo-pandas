# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
# !ls ../data/*.csv
# Out:
# ../data/2020_sharing_data_outside.csv  ../data/olympic_athlete_events.csv
# ../data/CPILFESL.csv		       ../data/san+francisco,ca.csv
# ../data/albany,ny.csv		       ../data/sat-scores.csv
# ../data/boston,ma.csv		       ../data/skyscrapers.csv
# ../data/burrito_current.csv	       ../data/springfield,il.csv
# ../data/celebrity_deaths_2016.csv      ../data/springfield,ma.csv
# ../data/chicago,il.csv		       ../data/taxi-distance.csv
# ../data/eu_cpi.csv		       ../data/taxi-passenger-count.csv
# ../data/eu_gdp.csv		       ../data/taxi.csv
# ../data/ice-cream.csv		       ../data/titanic3.csv
# ../data/languages.csv		       ../data/us-median-cpi.csv
# ../data/los+angeles,ca.csv	       ../data/us-unemployment-rate.csv
# ../data/miles-traveled.csv	       ../data/us_gdp.csv
# ../data/new+york,ny.csv		       ../data/winemag-150k-reviews.csv
# ../data/oecd_locations.csv	       ../data/wti-daily.csv
# ../data/oecd_tourism.csv

# %%
filename = '../data/taxi.csv'
df = pd.read_csv(filename)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (9999, 19)

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-06-02 11:19:29   2015-06-02 11:47:52                1
# 1         2  2015-06-02 11:19:30   2015-06-02 11:27:56                1
# 2         2  2015-06-02 11:19:31   2015-06-02 11:30:30                1
# 3         2  2015-06-02 11:19:31   2015-06-02 11:39:02                1
# 4         1  2015-06-02 11:19:32   2015-06-02 11:32:49                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.63        -73.954430        40.764141           1
# 1           0.46        -73.971443        40.758942           1
# 2           0.87        -73.978111        40.738434           1
# 3           2.13        -73.945892        40.773529           1
# 4           1.40        -73.979088        40.776772           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %%
dataFrame = pd.read_csv(filename)

# %%
dataFrame.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-06-02 11:19:29   2015-06-02 11:47:52                1
# 1         2  2015-06-02 11:19:30   2015-06-02 11:27:56                1
# 2         2  2015-06-02 11:19:31   2015-06-02 11:30:30                1
# 3         2  2015-06-02 11:19:31   2015-06-02 11:39:02                1
# 4         1  2015-06-02 11:19:32   2015-06-02 11:32:49                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.63        -73.954430        40.764141           1
# 1           0.46        -73.971443        40.758942           1
# 2           0.87        -73.978111        40.738434           1
# 3           2.13        -73.945892        40.773529           1
# 4           1.40        -73.979088        40.776772           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %%
type(dataFrame)
# Out:
# pandas.core.frame.DataFrame

# %%
10+10
# Out:
# 20

# %%
df
# Out:
#       VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0            2  2015-06-02 11:19:29   2015-06-02 11:47:52                1
# 1            2  2015-06-02 11:19:30   2015-06-02 11:27:56                1
# 2            2  2015-06-02 11:19:31   2015-06-02 11:30:30                1
# 3            2  2015-06-02 11:19:31   2015-06-02 11:39:02                1
# 4            1  2015-06-02 11:19:32   2015-06-02 11:32:49                1
# ...        ...                  ...                   ...              ...
# 9994         1  2015-06-01 00:12:59   2015-06-01 00:24:18                1
# 9995         1  2015-06-01 00:12:59   2015-06-01 00:28:16                1
# 9996         2  2015-06-01 00:13:00   2015-06-01 00:37:25                1
# 9997         2  2015-06-01 00:13:02   2015-06-01 00:19:10                6
# 9998         1  2015-06-01 00:13:04   2015-06-01 00:36:33                1
#
# ...

# %%
dataFrame.head(2)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-06-02 11:19:29   2015-06-02 11:47:52                1
# 1         2  2015-06-02 11:19:30   2015-06-02 11:27:56                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.63        -73.954430        40.764141           1
# 1           0.46        -73.971443        40.758942           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                  N         -73.974754         40.754093             2
# 1                  N         -73.978539         40.761909             1
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0         17.0    0.0      0.5         0.0           0.0
# 1          6.5    0.0      0.5         1.0           0.0
#
#    improvement_surcharge  total_amount
# 0                    0.3          17.8
# 1                    0.3           8.3

# %%
dataFrame.head(20)
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          2  2015-06-02 11:19:29   2015-06-02 11:47:52                1
# 1          2  2015-06-02 11:19:30   2015-06-02 11:27:56                1
# 2          2  2015-06-02 11:19:31   2015-06-02 11:30:30                1
# 3          2  2015-06-02 11:19:31   2015-06-02 11:39:02                1
# 4          1  2015-06-02 11:19:32   2015-06-02 11:32:49                1
# 5          1  2015-06-02 11:19:33   2015-06-02 11:28:48                1
# 6          1  2015-06-02 11:19:34   2015-06-02 11:38:46                1
# 7          1  2015-06-02 11:19:35   2015-06-02 12:36:46                4
# 8          2  2015-06-02 11:19:36   2015-06-02 11:45:19                1
# 9          1  2015-06-02 11:19:38   2015-06-02 11:23:50                1
# 10         2  2015-06-02 11:19:38   2015-06-02 11:19:43                3
# 11         2  2015-06-02 11:19:39   2015-06-02 11:36:43                1
# ...

# %%
dataFrame['trip_distance'].min()
# Out:
# 0.0

# %%
dataFrame['trip_distance'].max()
# Out:
# 64.6

# %%
dataFrame['trip_distance'].mean()
# Out:
# 3.1585108510851083

# %%
dataFrame['trip_distance'].count()
# Out:
# 9999

# %%
dataFrame['trip_distance'].sum() / dataFrame['trip_distance'].count()
# Out:
# 3.1585108510851083

# %%
dataFrame['trip_distance'].head()
# Out:
# 0    1.63
# 1    0.46
# 2    0.87
# 3    2.13
# 4    1.40
# Name: trip_distance, dtype: float64

# %%
dataFrame['trip_distance'].describe()
# Out:
# count    9999.000000
# mean        3.158511
# std         4.037516
# min         0.000000
# 25%         1.000000
# 50%         1.700000
# 75%         3.300000
# max        64.600000
# Name: trip_distance, dtype: float64

# %%
# %whos
# Out:
# Variable    Type         Data/Info
# ----------------------------------
# dataFrame   DataFrame          VendorID tpep_picku<...>n[9999 rows x 19 columns]
# df          DataFrame          VendorID tpep_picku<...>n[9999 rows x 19 columns]
# filename    str          ../data/taxi.csv
# pd          module       <module 'pandas' from '/h<...>ages/pandas/__init__.py'>

# %%
# %magic
# Out:
# IPython's 'magic' functions
# ...
#
# The magic function system provides a series of functions which allow you to
# control the behavior of IPython itself, plus a lot of system-type
# features. There are two kinds of magics, line-oriented and cell-oriented.
#
# Line magics are prefixed with the % character and work much like OS
# command-line calls: they get as an argument the rest of the line, where
# arguments are passed without parentheses or quotes.  For example, this will
# time the given statement::
#
#         %timeit range(1000)
#
# Cell magics are prefixed with a double %%, and they are functions that get as
# an argument not only the rest of the line, but also the lines below it in a
# separate argument.  These magics are called with two arguments: the rest of the
# call line and the body of the cell, consisting of the lines below the first.
# For example::
#
#         %%timeit x = numpy.random.randn((100, 100))
#         numpy.linalg.svd(x)
#
# ...

# %%
dataFrame['total_amount'].head(5).mean
# Out:
# <bound method Series.mean of 0    17.80
# 1     8.30
# 2    11.00
# 3    17.16
# 4    10.30
# Name: total_amount, dtype: float64>

# %%
dataFrame['total_amount'].describe
# Out:
# <bound method NDFrame.describe of 0       17.80
# 1        8.30
# 2       11.00
# 3       17.16
# 4       10.30
#         ...
# 9994    12.30
# 9995    20.30
# 9996    22.30
# 9997     7.80
# 9998    26.75
# Name: total_amount, Length: 9999, dtype: float64>

# %%
dataFrame['total_amount'].head()
# Out:
# 0    17.80
# 1     8.30
# 2    11.00
# 3    17.16
# 4    10.30
# Name: total_amount, dtype: float64

# %%
dataFrame['total_amount'].head(9999)
# Out:
# 0       17.80
# 1        8.30
# 2       11.00
# 3       17.16
# 4       10.30
#         ...
# 9994    12.30
# 9995    20.30
# 9996    22.30
# 9997     7.80
# 9998    26.75
# Name: total_amount, Length: 9999, dtype: float64

# %%
dataFrame['total_amount'].tail(20).mean()
# Out:
# 18.058500000000002

# %%
dataFrame['total_amount'].tail(21)
# Out:
# 9979    41.75
# 9980    31.30
# 9981    19.38
# 9982    28.80
# 9983     9.96
# 9984     7.30
# 9985     8.80
# 9986    21.35
# 9987     8.30
# 9988     8.50
# 9989     8.76
# 9990    26.62
# 9991     9.30
# 9992    23.30
# 9993    18.30
# 9994    12.30
# 9995    20.30
# 9996    22.30
# 9997     7.80
# 9998    26.75
# Name: total_amount, dtype: float64

# %%
(
    dataFrame
    ['total_amount']
    .tail(21)
    .mean
)
# Out:
# <bound method Series.mean of 9978     4.80
# 9979    41.75
# 9980    31.30
# 9981    19.38
# 9982    28.80
# 9983     9.96
# 9984     7.30
# 9985     8.80
# 9986    21.35
# 9987     8.30
# 9988     8.50
# 9989     8.76
# 9990    26.62
# 9991     9.30
# 9992    23.30
# 9993    18.30
# 9994    12.30
# 9995    20.30
# 9996    22.30
# 9997     7.80
# 9998    26.75
# Name: total_amount, dtype: float64>

# %%
dataFrame['total_amount'].describe()
# Out:
# count    9999.000000
# mean       17.552472
# std        15.137990
# min        -7.800000
# 25%         8.800000
# 50%        12.800000
# 75%        19.800000
# max       252.350000
# Name: total_amount, dtype: float64

# %%
dataFrame.describe()
# Out:
#           VendorID  passenger_count  trip_distance  pickup_longitude  \
# count  9999.000000      9999.000000    9999.000000       9999.000000
# mean      1.516652         1.659466       3.158511        -73.014956
# std       0.499748         1.333306       4.037516          8.347871
# min       1.000000         0.000000       0.000000        -74.186302
# 25%       1.000000         1.000000       1.000000        -73.990997
# 50%       2.000000         1.000000       1.700000        -73.979774
# 75%       2.000000         2.000000       3.300000        -73.963001
# max       2.000000         6.000000      64.600000          0.000000
#
#        pickup_latitude   RateCodeID  dropoff_longitude  dropoff_latitude  \
# count      9999.000000  9999.000000        9999.000000       9999.000000
# mean         40.226521     1.045105         -73.054699         40.248644
# std           4.599169     0.302132           8.186847          4.510520
# ...

# %%
dataFrame['total_distance','total_price']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.12.3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('total_distance', 'total_price')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 1
# ...

# %%
dataFrame[['total_amount','total_price']]
# Out:
#   Cell In[58], line 1
#     dataFrame.[['total_amount','total_price']]
#               ^
# SyntaxError: invalid syntax

# %%
dataFrame[ ['trip_distance', 'total_amount','passenger_count'] ].head(5).describe()
# Out:
#        trip_distance  total_amount  passenger_count
# count        5.00000      5.000000              5.0
# mean         1.29800     12.912000              1.0
# std          0.65159      4.292053              0.0
# min          0.46000      8.300000              1.0
# 25%          0.87000     10.300000              1.0
# 50%          1.40000     11.000000              1.0
# 75%          1.63000     17.160000              1.0
# max          2.13000     17.800000              1.0

# %%
dataFrame[ ['trip_distance', 'total_amount','passenger_count'] ].describe()
# Out:
#        trip_distance  total_amount  passenger_count
# count    9999.000000   9999.000000      9999.000000
# mean        3.158511     17.552472         1.659466
# std         4.037516     15.137990         1.333306
# min         0.000000     -7.800000         0.000000
# 25%         1.000000      8.800000         1.000000
# 50%         1.700000     12.800000         1.000000
# 75%         3.300000     19.800000         2.000000
# max        64.600000    252.350000         6.000000

# %%
dataFrame[ ['trip_distance', 'total_amount','passenger_count'] ].head(5)
# Out:
#    trip_distance  total_amount  passenger_count
# 0           1.63         17.80                1
# 1           0.46          8.30                1
# 2           0.87         11.00                1
# 3           2.13         17.16                1
# 4           1.40         10.30                1

# %%
dataFrame.loc[[0,1,2,3,4]]
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-06-02 11:19:29   2015-06-02 11:47:52                1
# 1         2  2015-06-02 11:19:30   2015-06-02 11:27:56                1
# 2         2  2015-06-02 11:19:31   2015-06-02 11:30:30                1
# 3         2  2015-06-02 11:19:31   2015-06-02 11:39:02                1
# 4         1  2015-06-02 11:19:32   2015-06-02 11:32:49                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.63        -73.954430        40.764141           1
# 1           0.46        -73.971443        40.758942           1
# 2           0.87        -73.978111        40.738434           1
# 3           2.13        -73.945892        40.773529           1
# 4           1.40        -73.979088        40.776772           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %%
dataFrame['trip_distance'].head(100).plot.line()
# Out:
# <Axes: >

# %%
dataFrame.head(100).hist()
# Out:
# array([[<Axes: title={'center': 'VendorID'}>,
#         <Axes: title={'center': 'passenger_count'}>,
#         <Axes: title={'center': 'trip_distance'}>,
#         <Axes: title={'center': 'pickup_longitude'}>],
#        [<Axes: title={'center': 'pickup_latitude'}>,
#         <Axes: title={'center': 'RateCodeID'}>,
#         <Axes: title={'center': 'dropoff_longitude'}>,
#         <Axes: title={'center': 'dropoff_latitude'}>],
#        [<Axes: title={'center': 'payment_type'}>,
#         <Axes: title={'center': 'fare_amount'}>,
#         <Axes: title={'center': 'extra'}>,
#         <Axes: title={'center': 'mta_tax'}>],
#        [<Axes: title={'center': 'tip_amount'}>,
#         <Axes: title={'center': 'tolls_amount'}>,
#         <Axes: title={'center': 'improvement_surcharge'}>,
#         <Axes: title={'center': 'total_amount'}>]], dtype=object)

# %%
dataFrame.head(20).plot().scatter()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 dataFrame.head(20).plot().scatter()
#
# File ~/.pyenv/versions/3.12.3/lib/python3.12/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# TypeError: Axes.scatter() missing 2 required positional arguments: 'x' and 'y'

# %%
dataFrame.plot.scatter(x='trip_distance', y='total_amount')
# Out:
# <Axes: xlabel='trip_distance', ylabel='total_amount'>

# %%
# I want to know how far did people travel in our data set?
# Let's see a histogram of those values

df['trip_distance'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>
