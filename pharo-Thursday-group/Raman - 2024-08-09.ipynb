# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
np.random.seed(0)
s = Series(np.random.randint(0, 100, 10),
           index=list('abcdefghij'))

s
# Out:
# a    44
# b    47
# c    64
# d    67
# e    67
# f     9
# g    83
# h    21
# i    36
# j    87
# dtype: int64

# %%
s.plot()
# Out:
# <Axes: >

# %%
s.plot.line()
# Out:
# <Axes: >

# %%
s.plot.line(title='The plot thickens',
            color='red', 
            ylim=(-10, 100) )
# Out:
# <Axes: title={'center': 'The plot thickens'}>

# %%
s.plot.bar()
# Out:
# <Axes: >

# %%
s.plot.barh()
# Out:
# <Axes: >

# %%
s.sort_index(ascending=False).plot.barh()
# Out:
# <Axes: >

# %%
s.plot.line(
    title = 'The PnL is Red',
    color = 'red',
    ylim=[0,100])
# Out:
# <Axes: title={'center': 'The PnL is Red'}>

# %%
high_temps = Series([34, 33, 33, 34, 35, 35, 35, 34, 33, 34],
                    index='0809 0810 0811 0812 0813 0814 0815 0816 0817 0818'.split())
high_temps
# Out:
# 0809    34
# 0810    33
# 0811    33
# 0812    34
# 0813    35
# 0814    35
# 0815    35
# 0816    34
# 0817    33
# 0818    34
# dtype: int64

# %%
high_temps.plot.line(
    title = 'High Temps in Barca',
    ylim = [25,40]
)
# Out:
# <Axes: title={'center': 'High Temps in Barca'}>

# %%
high_temps.plot.bar(
    title = 'High Temps in Barca',
    color = 'black'
)
# Out:
# <Axes: title={'center': 'High Temps in Barca'}>

# %%
high_temps.plot.pie()
# Out:
# <Axes: >

# %%
high_temps.value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
budget = Series (
    [50,100,20,100,75],
    index = ['food','rent','tube','party','coffee']
)
budget.plot.pie()
# Out:
# <Axes: >

# %%
high_temps.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
high_temps.plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df = pd.read_csv('../data/nyc_taxi_2020-07.csv',
                usecols=['passenger_count', 'total_amount', 'trip_distance'])
df
# Out:
#         passenger_count  trip_distance  total_amount
# 0                   1.0           1.50          9.30
# 1                   1.0           9.50         27.80
# 2                   1.0           5.85         22.30
# 3                   1.0           1.90         14.16
# 4                   1.0           1.25          7.80
# ...                 ...            ...           ...
# 800407              NaN          24.23         83.50
# 800408              NaN           4.40         19.78
# 800409              NaN           8.78         38.45
# 800410              NaN           6.50         29.77
# 800411              NaN          10.88         51.90
#
# [800412 rows x 3 columns]

# %%
df.dtypes
# Out:
# passenger_count    float64
# trip_distance      float64
# total_amount       float64
# dtype: object

# %%
df['passenger_count'].value_counts()
# Out:
# passenger_count
# 1.0    566009
# 2.0     90900
# 3.0     21778
# 0.0     19506
# 5.0     17107
# 6.0     14447
# 4.0      7810
# 7.0         5
# 8.0         2
# 9.0         1
# Name: count, dtype: int64

# %%
df['passenger_count'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
df['trip_length_category'] = 'medium'

# %%
df.loc[
    df['trip_distance']<=1
    ,
    'trip_length_category'
] = 'short'

# %%
df.loc[
    df['trip_distance']>10
    ,
    'trip_length_category'
] = 'long'

# %%
pd.cut(df['trip_distance'],
       bins=[-10, 1, 10, 100000],
       labels=['short', 'medium', 'long']).value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
df['total_amount'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['total_amount'].describe()
# Out:
# count    800412.000000
# mean         18.631460
# std          15.060771
# min        -397.600000
# 25%          10.800000
# 50%          14.160000
# 75%          20.550000
# max        1995.000000
# Name: total_amount, dtype: float64

# %%
high_temps.plot.box()
# Out:
# <Axes: >

# %%
# let's make one temp very high

high_temps.loc['0812'] = 50
high_temps.plot.box()
# Out:
# <Axes: >

# %%
temps = DataFrame({'hi':[32, 33, 33, 33, 34, 34, 35, 34, 34, 34],
                   'lo':[23, 23, 24, 23, 23, 23, 23, 23, 23, 23]},
                   index='0809 0810 0811 0812 0813 0814 0815 0816 0817 0818'.split())
temps
# Out:
#       hi  lo
# 0809  32  23
# 0810  33  23
# 0811  33  24
# 0812  33  23
# 0813  34  23
# 0814  34  23
# 0815  35  23
# 0816  34  23
# 0817  34  23
# 0818  34  23

# %%
temps.plot.line()
# Out:
# <Axes: >

# %%
temps.plot.bar()
# Out:
# <Axes: >

# %%
temps.value_counts().plot.pie(subplots=True)
# Out:
# hi             Axes(0.125,0.11;0.227941x0.77)
# lo          Axes(0.398529,0.11;0.227941x0.77)
# humidity    Axes(0.672059,0.11;0.227941x0.77)
# dtype: object

# %%
temps.plot.box(subplots=True)
# Out:
# hi             Axes(0.125,0.11;0.227941x0.77)
# lo          Axes(0.398529,0.11;0.227941x0.77)
# humidity    Axes(0.672059,0.11;0.227941x0.77)
# dtype: object

# %%
temps['humidity'] = [80, 75, 50, 70, 82, 90, 82, 86, 81, 70]
temps
# Out:
#       hi  lo  humidity
# 0809  32  23        80
# 0810  33  23        75
# 0811  33  24        50
# 0812  33  23        70
# 0813  34  23        82
# 0814  34  23        90
# 0815  35  23        82
# 0816  34  23        86
# 0817  34  23        81
# 0818  34  23        70

# %%
df[['trip_distance','total_amount']].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[['trip_distance','total_amount']].plot.hist(subplots=True)
# Out:
# array([<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#       dtype=object)

# %%
df.loc[
    ((df['total_amount'] < 1000) & (df['trip_distance'] < 200) ),
    ['trip_distance','total_amount']
].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.head(200)[['trip_distance','total_amount']].plot.line(subplots=False)
# Out:
# <Axes: >

# %%
df[['trip_distance','total_amount','passenger_count']].plot.box(subplots=False)
# Out:
# <Axes: >

# %%
df[['trip_distance','total_amount','passenger_count']].plot.box(subplots=True)
# Out:
# trip_distance         Axes(0.125,0.11;0.227941x0.77)
# total_amount       Axes(0.398529,0.11;0.227941x0.77)
# passenger_count    Axes(0.672059,0.11;0.227941x0.77)
# dtype: object

# %%
df = pd.read_csv('../data/nyc_taxi_2020-07.csv')
# Out:
# /tmp/ipykernel_440323/544045659.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/nyc_taxi_2020-07.csv')
