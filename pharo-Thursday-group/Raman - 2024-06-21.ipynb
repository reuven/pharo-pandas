# %%
import pandas as pd

filename = '../data/taxi.csv'  

df = pd.read_csv(filename)

df
# Out:
#       VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0            2  2015-06-02 11:19:29   2015-06-02 11:47:52                1
# 1            2  2015-06-02 11:19:30   2015-06-02 11:27:56                1
# 2            2  2015-06-02 11:19:31   2015-06-02 11:30:30                1
# 3            2  2015-06-02 11:19:31   2015-06-02 11:39:02                1
# 4            1  2015-06-02 11:19:32   2015-06-02 11:32:49                1
# ...        ...                  ...                   ...              ...
# 9994         1  2015-06-01 00:12:59   2015-06-01 00:24:18                1
# 9995         1  2015-06-01 00:12:59   2015-06-01 00:28:16                1
# 9996         2  2015-06-01 00:13:00   2015-06-01 00:37:25                1
# 9997         2  2015-06-01 00:13:02   2015-06-01 00:19:10                6
# 9998         1  2015-06-01 00:13:04   2015-06-01 00:36:33                1
#
# ...

# %%
import numpy as np
from pandas import Series, DataFrame

np.random.seed(0)

df = DataFrame(np.random.randint(0,1000,[4,5]))
df
# Out:
#      0    1    2    3    4
# 0  684  559  629  192  835
# 1  763  707  359    9  723
# 2  277  754  804  599   70
# 3  472  600  396  314  705

# %%
df.to_csv('mydata.csv', header=None)   # don't write the header row

# %%
df2 = pd.read_csv('mydata.csv',header=None)
df2
# Out:
#    0  684  559  629  192  835
# 0  1  763  707  359    9  723
# 1  2  277  754  804  599   70
# 2  3  472  600  396  314  705

# %%
df2 = pd.read_csv('../data/airlines.dat',
                  usecols=[1,3,5,6],
                  header=None,
                  sep=',',
                  names=['airline name', 'airline code', 'airline full name', 'country'],
                    )

# %%
df2['country'].head()
# Out:
# 0               NaN
# 1     United States
# 2      South Africa
# 3    United Kingdom
# 4            Russia
# Name: country, dtype: object

# %%
df2['country'].value_counts().head(15)
# Out:
# country
# United States     1080
# Mexico             439
# United Kingdom     407
# Canada             318
# Russia             230
# Spain              166
# Germany            131
# France             119
# Australia           93
# South Africa        91
# Italy               90
# Ukraine             89
# Nigeria             85
# Kazakhstan          79
# Sweden              70
# Name: count, dtype: int64

# %%
# Excel
filename = '../data/titanic3.xls'

df = pd.read_excel(filename)

# %%
df.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
df['age'].mean()
# Out:
# 29.8811345124283

# %%
df.loc[
    df['survived']==0,
    'age'
].mean()
# Out:
# 30.54536882067851
