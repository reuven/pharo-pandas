# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
filename = '../data/winemag-150k-reviews.csv'
df = pd.read_csv(filename)

# %%
df.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
df.loc[0,'description'] # row index 0, column description
# Out:
# 'This tremendous 100% varietal wine hails from Oakville and was aged over three years in oak. Juicy red-cherry fruit and a compelling hint of caramel greet the palate, framed by elegant, fine tannins and a subtle minty tone in the background. Balanced and rewarding from start to finish, it has years ahead of it to develop further nuance. Enjoy 2022–2030.'

# %%
# use vectorization capabilities of pandas
# pandas.str
# which is an attribute on string collumns to invoke methods

df['country'].str.len()
# Out:
# 0         2.0
# 1         5.0
# 2         2.0
# 3         2.0
# 4         6.0
#          ...
# 150925    5.0
# 150926    6.0
# 150927    5.0
# 150928    6.0
# 150929    5.0
# Name: country, Length: 150930, dtype: float64

# %%
df.loc[df['country'].str.len() > 5]
# Out:
#         Unnamed: 0      country  \
# 4                4       France
# 13              13       France
# 18              18       France
# 25              25  New Zealand
# 30              30     Bulgaria
# ...            ...          ...
# 150921      150921       France
# 150923      150923       France
# 150924      150924       France
# 150926      150926       France
# 150928      150928       France
#
#                                               description  \
# 4       This is the top wine from La Bégude, named aft...
# 13      This wine is in peak condition. The tannins an...
# 18      Coming from a seven-acre vineyard named after ...
# 25      Yields were down in 2015, but intensity is up,...
# 30      This Bulgarian Mavrud presents the nose with s...
# ...                                                   ...
# 150921  Shows some older notes: a bouquet of toasted w...
# 150923  Rich and toasty, with tiny bubbles. The bouque...
# ...

# %%
top25 = df['description'].str.len().quantile(.75)
df1 = df.loc[df['description'].str.len() > top25]
df1['points'].mean()
# Out:
# 90.04736898510342

# %%
bottom25 = df['description'].str.len().quantile(.25)
df2 = df.loc[df['description'].str.len() < bottom25]
df2['points'].mean()
# Out:
# 85.81286768638357

# %%
df.loc[
    df['description'].str.len() >= df['description'].str.len().quantile(0.75) #
,
    'points'
].mean()
# Out:
# 90.02646323819545

# %%
df['country'].str.lower()
# Out:
# 0             us
# 1          spain
# 2             us
# 3             us
# 4         france
#            ...
# 150925     italy
# 150926    france
# 150927     italy
# 150928    france
# 150929     italy
# Name: country, Length: 150930, dtype: object

# %%
df.loc[
    df['description'].str.contains('x')
]
# Out:
#         Unnamed: 0 country                                        description  \
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# 5                5   Spain  Deep, dense and pure from the opening bell, th...
# 6                6   Spain  Slightly gritty black-fruit aromas include a s...
# ...            ...     ...                                                ...
# 150921      150921  France  Shows some older notes: a bouquet of toasted w...
# 150922      150922   Italy  Made by 30-ish Roberta Borghese high above Man...
# 150923      150923  France  Rich and toasty, with tiny bubbles. The bouque...
# 150924      150924  France  Really fine for a low-acid vintage, there's an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
#
# ...

# %%
# wines from countries containing J or j

df['country'].str.contains('j', case=False).value_counts()
# Out:
# country
# False    150923
# True          2
# Name: count, dtype: int64

# %%
df['description'].str.get(5)
# Out:
# 0         t
# 1         a
# 2         a
# 3         s
# 4         i
#          ..
# 150925    p
# 150926    s
# 150927    c
# 150928    f
# 150929    P
# Name: description, Length: 150930, dtype: object

# %%
(
    df['description']
    .str
    .split()
    .str
    .get(0)
    .value_counts()
)
# Out:
# description
# This           25499
# A              19389
# The             7694
# Here's          2970
# An              2128
#                ...
# Symmetry           1
# Nanfrè             1
# Villalta's         1
# Pineapples,        1
# Oreo               1
# Name: count, Length: 6988, dtype: int64

# %%
# what if I have a series of strings that mostly contain digits
s = Series('10 20 30 hello 40 50'.split())
s
# Out:
# 0       10
# 1       20
# 2       30
# 3    hello
# 4       40
# 5       50
# dtype: object

# %%
s.loc[s.str.isdigit()].astype(int)
# Out:
# 0    10
# 1    20
# 2    30
# 4    40
# 5    50
# dtype: int64
