# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np

# %%
np.random.seed(0)

# %%
s = Series(np.random.randint(0,100,10),index=list('abcdefghij'))

# %%
s.name = 'Rates'
s.plot.line(title='Great plot!', color='red', legend=True)
# Out:
# <Axes: title={'center': 'Great plot!'}>

# %%
temps = Series(np.random.randint(50,100,10),index=['0801','0802','0803','0804','0805','0806','0807','0808','0809','0810'])

# %%
temps.plot.line(title='Temp Plot',ylim=(-40,130))
# Out:
# <Axes: title={'center': 'Temp Plot'}>

# %%
temps.plot.bar(title='Daily Temps',color='orange')
# Out:
# <Axes: title={'center': 'Daily Temps'}>

# %%
filename2 = '../data/taxi.csv'

# %%
df = pd.read_csv(filename2)

# %%
df['passenger_count'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
df[['trip_distance','total_amount']].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[['trip_distance','total_amount']].plot.hist(subplots=True)
# Out:
# array([<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#       dtype=object)

# %%
df[['trip_distance','total_amount']].head(200).plot.line()
# Out:
# <Axes: >

# %%
df[['passenger_count','trip_distance','total_amount']].plot.box()
# Out:
# <Axes: >

# %%
df[['passenger_count','trip_distance','total_amount']].plot.box(subplots=True)
# Out:
# passenger_count       Axes(0.125,0.11;0.227941x0.77)
# trip_distance      Axes(0.398529,0.11;0.227941x0.77)
# total_amount       Axes(0.672059,0.11;0.227941x0.77)
# dtype: object

# %%
df[['fare_amount','extra','mta_tax','tip_amount','tolls_amount','improvement_surcharge']].head(10)
# Out:
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0         17.0    0.0      0.5        0.00          0.00
# 1          6.5    0.0      0.5        1.00          0.00
# 2          8.0    0.0      0.5        2.20          0.00
# 3         13.5    0.0      0.5        2.86          0.00
# 4          9.5    0.0      0.5        0.00          0.00
# 5          8.0    0.0      0.5        1.75          0.00
# 6         12.5    0.0      0.5        3.00          0.00
# 7         52.5    0.0      0.5       15.00          5.54
# 8         15.0    0.0      0.5        0.00          0.00
# 9          5.0    0.0      0.5        0.50          0.00
#
#    improvement_surcharge
# 0                    0.3
# 1                    0.3
# 2                    0.3
# 3                    0.3
# 4                    0.3
# 5                    0.3
# 6                    0.3
# 7                    0.3
# 8                    0.3
# 9                    0.3

# %%
df[['fare_amount','extra','mta_tax','tip_amount','tolls_amount','improvement_surcharge']].head(10).plot.bar(stacked=True)
# Out:
# <Axes: >
